# %% [markdown]
# # A. answers

# %%
# 1.'Todayis a great day'
# 2.'Today is a great day'
#3. True
#4. True
#5. 8
#6. true
#7.str('hello') is a valid statement,because 'hello' is called by using string function
#8.true
#9.98 # ASCII value of b
#10.id(object)

# %%
# B. string is a set of charecters and raw string is used for printing purpose.
# c. Yes,because '101'is an int value and it is store in a result variable.
# D. 10
# E. 0b0111
# F. def number(n):
#         return len(n)

# G. list=[1,2,3] 
#   def list_number(n):
#        return n*2

# H. MUTABILITY: we can change the value during execution of the program
#    IMMUTABILITY: once we assigned the value to the variable,we can"t change the value

# I. NO, because tuples are immutable,it does not accepts item update.
# J.  sequence=[1,2,3]
#     list(lambda sequence: return seq )

# K. -3
#    -2

# L. false
# M. 

# N. n=-1
#    while (n):
#       print('value of n is {}'.format(n))
#       n-=1

# O. a=2
#    b=3
#    while a>b:
#       print(f'the greatest number is {a}')

# P. def func(self,*args,*kwargs):
#           self.args=args
#           self.kwargs=kwargs
#           print(' the args values are {}'.format(args))
#           print(' the kwargs values are {}'.format(kwargs))

# Q. @classmethod: used for calling class level attributes
#    @staticmethod:used for calling both calss level attributes as well as object level attributes i.e without using self object

# R. import sqlite3 as sq
#     con=sq.connect('raghu.db')
#    def create_table():
#      cur=con.cursor()
#       cur.execute('create table if not exists RAGHU(name TEXT,_id INT,age INT,profession TEXT)')
#        print('table created')
#        con.commit()
#    def insert_data():
#        name=input('enter name')
#        _id=input('enter id')
#        age=input('enter age')
#        profession=input('enter profession')
#        cur=con.cursor()
#        cur.execute('insert into RAGHU values(?,?,?,?)',(name,age,_id,profession))
#        con.commit()
#        con.close()
#    def del_data():
#       del name
#    def update_data(self)
#       self.age=age


# s. import re
#    def create_file('raghu.txt):
#                print('file created ')
#    def write_file(self):
#                f=open('raghu.txt',w)
#                f.writelines('hi ')
#    def read_file(self):
#                f=open('raghu.txt',r)
#                f.read()
#    def search_file(self):
#                pattern=r'\d'
#                result=re.search(pattern,'raghu.txt')
#                print(result.group)
#        
#
